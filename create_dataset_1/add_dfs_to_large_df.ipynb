# %%
import pandas as pd
import csv 
import os

def load_csv_dataset(file_path):
    return pd.read_csv(file_path)

# %%
big_df = load_csv_dataset('updated COMBINED DF_WORKING.csv')
len(big_df)
# Out:
# 62313

# %%
#leagues value
leagues_value = load_csv_dataset('/Users/finneganlaister-smith/Downloads/DEV ENVIRONMENT/data-science-jupyter-template-main/footy_project_market_value_rankings/create_dataset_1/Most Updated Edited Transfermarkt Dataset.csv')
#leagues value large 
leagues_value_large = load_csv_dataset('/Users/finneganlaister-smith/Downloads/DEV ENVIRONMENT/data-science-jupyter-template-main/footy_project_market_value_rankings/create_dataset_1/most_updated_transfermarkt_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 #leagues value
# ----> 2 leagues_value = load_csv_dataset('/Users/finneganlaister-smith/Downloads/DEV ENVIRONMENT/data-science-jupyter-template-main/footy_project_market_value_rankings/create_dataset_1/Most Updated Edited Transfermarkt Dataset.csv')
#       3 #leagues value large
#       4 leagues_value_large = load_csv_dataset('/Users/finneganlaister-smith/Downloads/DEV ENVIRONMENT/data-science-jupyter-template-main/footy_project_market_value_rankings/create_dataset_1/most_updated_transfermarkt_dataset.csv')
#
# Cell In[2], line 6, in load_csv_dataset(file_path)
#       5 def load_csv_dataset(file_path):
# ----> 6     return pd.read_csv(file_path)
#
# ...

# %% [markdown]
# ## Adding new DF - April 19

# %%
new_df = load_csv_dataset('Terrell Lookup Cases - new_df rework.csv')

# %%
big_df = big_df.drop(columns={'Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0'})
big_df
# Out:
#        Match ID                         Competition  \
# 0          3133  World Cup Qualifiers, Europe, 2018
# 1          3133  World Cup Qualifiers, Europe, 2018
# 2          3133  World Cup Qualifiers, Europe, 2018
# 3          3133  World Cup Qualifiers, Europe, 2018
# 4          3133  World Cup Qualifiers, Europe, 2018
# ...         ...                                 ...
# 62308      1516            Nations League 2018-2020
# 62309      1516            Nations League 2018-2020
# 62310      1516            Nations League 2018-2020
# 62311      1516            Nations League 2018-2020
# 62312      1516            Nations League 2018-2020
#
#                              Match        Date Nationality Team Country Code  \
# 0             Luxembourg vs France  25-03-2017  Luxembourg                LU
# 1             Luxembourg vs France  25-03-2017  Luxembourg                LU
# 2             Luxembourg vs France  25-03-2017  Luxembourg                LU
# ...

# %%
new_df = new_df.drop(columns={'Unnamed: 0.1', 'Unnamed: 0'})
new_df
# Out:
#        Match ID                         Competition  \
# 0          3137  World Cup Qualifiers, Europe, 2018
# 1          3179  World Cup Qualifiers, Europe, 2018
# 2          2685    World Cup Qualifiers, Asia, 2022
# 3          2691    World Cup Qualifiers, Asia, 2022
# 4          2693    World Cup Qualifiers, Asia, 2022
# ...         ...                                 ...
# 10232      3017  World Cup Qualifiers, Europe, 2018
# 10233      3238  World Cup Qualifiers, Europe, 2022
# 10234      3247  World Cup Qualifiers, Europe, 2022
# 10235      3248  World Cup Qualifiers, Europe, 2022
# 10236      3274  World Cup Qualifiers, Europe, 2022
#
#                                              Match        Date    Nationality  \
# 0                     Switzerland vs Faroe Islands  13-11-2016  Faroe Islands
# 1                           Liechtenstein vs Italy  12-11-2016  Liechtenstein
# 2                                 Maldives vs Guam  19-11-2019           Guam
# ...

# %%
big_df_merged_new_Df = pd.concat([big_df, new_df], ignore_index=True)

# %%
for index, row in big_df_merged_new_Df.iterrows():
    if row['Market Value'] == 0 and row['Impute Required?'] == False:
        big_df_merged_new_Df.at[index, 'Impute Required?'] = True

# %% [markdown]
# ## Merging with wrong DF

# %%
wrong_df = load_csv_dataset('Terrell Lookup Cases - wrong_df rework.csv')
wrong_df = wrong_df.drop(columns={'Unnamed: 0.1', 'Unnamed: 0'})
wrong_df
# Out:
#       Match ID                         Competition  \
# 0         3147  World Cup Qualifiers, Europe, 2018
# 1         3147  World Cup Qualifiers, Europe, 2018
# 2         2685    World Cup Qualifiers, Asia, 2022
# 3         2685    World Cup Qualifiers, Asia, 2022
# 4         2685    World Cup Qualifiers, Asia, 2022
# ...        ...                                 ...
# 1058      3715                      Gold Cup, 2017
# 1059      2998  World Cup Qualifiers, Europe, 2018
# 1060      3008  World Cup Qualifiers, Europe, 2018
# 1061      3024  World Cup Qualifiers, Europe, 2018
# 1062      1482            Nations League 2018-2020
#
#                              Match        Date Nationality Team Country Code  \
# 0     San Marino vs Czech Republic  26-03-2017  San Marino                SM
# 1     San Marino vs Czech Republic  26-03-2017  San Marino                SM
# 2                 Maldives vs Guam  19-11-2019        Guam                GU
# ...

# %%
wrong_df['Name(s) Found'] = wrong_df['New Found Name']
wrong_df
# Out:
#       Match ID                         Competition  \
# 0         3147  World Cup Qualifiers, Europe, 2018
# 1         3147  World Cup Qualifiers, Europe, 2018
# 2         2685    World Cup Qualifiers, Asia, 2022
# 3         2685    World Cup Qualifiers, Asia, 2022
# 4         2685    World Cup Qualifiers, Asia, 2022
# ...        ...                                 ...
# 1058      3715                      Gold Cup, 2017
# 1059      2998  World Cup Qualifiers, Europe, 2018
# 1060      3008  World Cup Qualifiers, Europe, 2018
# 1061      3024  World Cup Qualifiers, Europe, 2018
# 1062      1482            Nations League 2018-2020
#
#                              Match        Date Nationality Team Country Code  \
# 0     San Marino vs Czech Republic  26-03-2017  San Marino                SM
# 1     San Marino vs Czech Republic  26-03-2017  San Marino                SM
# 2                 Maldives vs Guam  19-11-2019        Guam                GU
# ...

# %%
# 2. Drop the column "Wrong Name"
wrong_df.drop(columns=['Wrong Name'], inplace=True)

# 3. Drop the column "status II"
wrong_df.drop(columns=['Status II'], inplace=True)

# 4. Drop the column "Found Name"
wrong_df.drop(columns=['Found Name'], inplace=True)

# 5. Drop the column "New Found Name"
wrong_df.drop(columns=['New Found Name'], inplace=True)

# %%
for index, row in wrong_df.iterrows():
    if row['Market Value'] == 0 and row['Impute Required?'] == False:
        wrong_df.at[index, 'Impute Required?'] = True

# %%
wrong_df
# Out:
#       Match ID                         Competition  \
# 0         3147  World Cup Qualifiers, Europe, 2018
# 1         3147  World Cup Qualifiers, Europe, 2018
# 2         2685    World Cup Qualifiers, Asia, 2022
# 3         2685    World Cup Qualifiers, Asia, 2022
# 4         2685    World Cup Qualifiers, Asia, 2022
# ...        ...                                 ...
# 1058      3715                      Gold Cup, 2017
# 1059      2998  World Cup Qualifiers, Europe, 2018
# 1060      3008  World Cup Qualifiers, Europe, 2018
# 1061      3024  World Cup Qualifiers, Europe, 2018
# 1062      1482            Nations League 2018-2020
#
#                              Match        Date Nationality Team Country Code  \
# 0     San Marino vs Czech Republic  26-03-2017  San Marino                SM
# 1     San Marino vs Czech Republic  26-03-2017  San Marino                SM
# 2                 Maldives vs Guam  19-11-2019        Guam                GU
# ...

# %%
big_df_merged_new_Df = pd.concat([big_df_merged_new_Df, wrong_df], ignore_index=True)

# %%
big_df_merged_new_Df.to_csv('most_updated_combined_DF.csv')

# %% [markdown]
# ## Group 1 Combined (DONE)

# %%
big_df_latest = load_csv_dataset('most_updated_combined_DF.csv')
big_df_latest = big_df_latest.drop(columns={'Unnamed: 0'})
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_98949/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)

# %%
big_df_latest
# Out:
#        Match ID                         Competition  \
# 0          3133  World Cup Qualifiers, Europe, 2018
# 1          3133  World Cup Qualifiers, Europe, 2018
# 2          3133  World Cup Qualifiers, Europe, 2018
# 3          3133  World Cup Qualifiers, Europe, 2018
# 4          3133  World Cup Qualifiers, Europe, 2018
# ...         ...                                 ...
# 73608      3715                      Gold Cup, 2017
# 73609      2998  World Cup Qualifiers, Europe, 2018
# 73610      3008  World Cup Qualifiers, Europe, 2018
# 73611      3024  World Cup Qualifiers, Europe, 2018
# 73612      1482            Nations League 2018-2020
#
#                              Match        Date Nationality Team Country Code  \
# 0             Luxembourg vs France  25-03-2017  Luxembourg                LU
# 1             Luxembourg vs France  25-03-2017  Luxembourg                LU
# 2             Luxembourg vs France  25-03-2017  Luxembourg                LU
# ...

# %%
group_1_working = load_csv_dataset('Group 1 and 2 (for T) - Find their $ Info/Terrell Lookup Cases - group1_success_rework.csv')
group_1_working = group_1_working.drop(columns={'Unnamed: 0.1', 'Unnamed: 0'})
group_1_working.rename(columns={'Names_Found': 'Name(s) Found'}, inplace=True)
group_1_working.rename(columns={'Country Code': 'Team Country Code'}, inplace=True)
group_1_working = group_1_working.assign(Name=group_1_working['Name(s) Found'])
group_1_working['Impute Required?'] = False
group_1_working['Match Case'] = 'single'

for i in range(0, 5260):
    if group_1_working.at[i, 'Market Value'] == 0:
        group_1_working.at[i, 'Impute Required?'] = True


desired_column_order = ['Match ID', 'Competition', 'Match', 'Date', 'Nationality', 'Team Country Code', 
                       'Season', 'Status', 'Name', 'Market Value', 'Lookup Still Required?', 
                       'Lookup Return Case', 'Impute Required?', 'Name(s) Found', 'ORIGINAL JERSEY', 
                       'Match Case']

group_1_working = group_1_working.reindex(columns=desired_column_order)
group_1_working
# Out:
#       Match ID                         Competition  \
# 0         1825            Nations League 2022-2023
# 1         1825            Nations League 2022-2023
# 2         1826            Nations League 2022-2023
# 3         1827            Nations League 2022-2023
# 4         1827            Nations League 2022-2023
# ...        ...                                 ...
# 5255      2128  World Cup Qualifiers, Africa, 2022
# 5256      2139  World Cup Qualifiers, Africa, 2022
# 5257      2145  World Cup Qualifiers, Africa, 2022
# 5258      3236  World Cup Qualifiers, Europe, 2022
# 5259      3265  World Cup Qualifiers, Europe, 2022
#
#                             Match        Date       Nationality  \
# 0                Cyprus vs Greece    24.09.22            Cyprus
# 1                Cyprus vs Greece    24.09.22            Cyprus
# 2      Greece vs Northern Ireland    27.09.22  Northern Ireland
# 3                Kosovo vs Cyprus    27.09.22            Kosovo
# ...

# %%
big_df_merged_new_Df = pd.concat([big_df_latest, group_1_working], ignore_index=True)
big_df_merged_new_Df
# Out:
#        Match ID                         Competition  \
# 0          3133  World Cup Qualifiers, Europe, 2018
# 1          3133  World Cup Qualifiers, Europe, 2018
# 2          3133  World Cup Qualifiers, Europe, 2018
# 3          3133  World Cup Qualifiers, Europe, 2018
# 4          3133  World Cup Qualifiers, Europe, 2018
# ...         ...                                 ...
# 78868      2128  World Cup Qualifiers, Africa, 2022
# 78869      2139  World Cup Qualifiers, Africa, 2022
# 78870      2145  World Cup Qualifiers, Africa, 2022
# 78871      3236  World Cup Qualifiers, Europe, 2022
# 78872      3265  World Cup Qualifiers, Europe, 2022
#
#                              Match        Date    Nationality  \
# 0             Luxembourg vs France  25-03-2017     Luxembourg
# 1             Luxembourg vs France  25-03-2017     Luxembourg
# 2             Luxembourg vs France  25-03-2017     Luxembourg
# 3             Luxembourg vs France  25-03-2017     Luxembourg
# ...

# %%
big_df_merged_new_Df.to_csv('big_df_merged(group 1 added).csv')

# %% [markdown]
# ## Match Date Filter left 0, Large Dataset said 0 (DONE)

# %%
match_date_filter_left_0 = load_csv_dataset('Group 1 and 2 (for T) - Find their $ Info/Terrell Lookup Cases - match_date_filter_said_0_success_rework.csv')
match_date_filter_left_0 = match_date_filter_left_0.drop(columns={'Unnamed: 0.1', 'Unnamed: 0', 'Status New'})

large_dataset_said_0 = load_csv_dataset('Group 1 and 2 (for T) - Find their $ Info/Terrell Lookup Cases - lg_dataset_said_0_complete_success_rework.csv')
large_dataset_said_0 = large_dataset_said_0.drop(columns={'Unnamed: 0.1', 'Unnamed: 0', 'Status New'})

combined_df = load_csv_dataset('big_df_merged(group 1 added).csv')
combined_df = combined_df.drop(columns={'Unnamed: 0'})
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_98949/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)

# %%
combined_df
# Out:
#        Match ID                         Competition  \
# 0          3133  World Cup Qualifiers, Europe, 2018
# 1          3133  World Cup Qualifiers, Europe, 2018
# 2          3133  World Cup Qualifiers, Europe, 2018
# 3          3133  World Cup Qualifiers, Europe, 2018
# 4          3133  World Cup Qualifiers, Europe, 2018
# ...         ...                                 ...
# 78868      2128  World Cup Qualifiers, Africa, 2022
# 78869      2139  World Cup Qualifiers, Africa, 2022
# 78870      2145  World Cup Qualifiers, Africa, 2022
# 78871      3236  World Cup Qualifiers, Europe, 2022
# 78872      3265  World Cup Qualifiers, Europe, 2022
#
#                              Match        Date    Nationality  \
# 0             Luxembourg vs France  25-03-2017     Luxembourg
# 1             Luxembourg vs France  25-03-2017     Luxembourg
# 2             Luxembourg vs France  25-03-2017     Luxembourg
# 3             Luxembourg vs France  25-03-2017     Luxembourg
# ...

# %%
match_date_filter_left_0
# Out:
#      Match ID                         Competition  \
# 0        3181  World Cup Qualifiers, Europe, 2018
# 1        2688    World Cup Qualifiers, Asia, 2022
# 2        2689    World Cup Qualifiers, Asia, 2022
# 3        2698    World Cup Qualifiers, Asia, 2022
# 4        2702    World Cup Qualifiers, Asia, 2022
# ..        ...                                 ...
# 303      2172  World Cup Qualifiers, Africa, 2022
# 304       275                      World Cup 2018
# 305       278                      World Cup 2018
# 306       280                      World Cup 2018
# 307      3015  World Cup Qualifiers, Europe, 2018
#
#                                Match        Date Nationality  \
# 0                  Turkey vs Iceland  06-10-2017      Turkey
# 1               Afghanistan vs Qatar  19-11-2019       Qatar
# 2                      Oman vs India  19-11-2019        Oman
# 3                    Oman vs Vietnam  12-10-2021     Vietnam
# ...

# %%
large_dataset_said_0
# Out:
#      Match ID                         Competition  \
# 0        3169  World Cup Qualifiers, Europe, 2018
# 1        2686    World Cup Qualifiers, Asia, 2022
# 2        2691    World Cup Qualifiers, Asia, 2022
# 3        2699    World Cup Qualifiers, Asia, 2022
# 4        2710    World Cup Qualifiers, Asia, 2026
# ..        ...                                 ...
# 448      2153  World Cup Qualifiers, Africa, 2022
# 449      2163  World Cup Qualifiers, Africa, 2022
# 450      3695                      Gold Cup, 2017
# 451      3732                      Gold Cup, 2019
# 452      3736                      Gold Cup, 2019
#
#                              Match        Date          Nationality  \
# 0            Germany vs San Marino  10-06-2017           San Marino
# 1      Turkmenistan vs North Korea  14-11-2019          North Korea
# 2            Cambodia vs Hong Kong  05-09-2019             Cambodia
# 3                  Kuwait vs Nepal  05-09-2019               Kuwait
# ...

# %%
combined_df_merged = pd.concat([combined_df, match_date_filter_left_0, large_dataset_said_0], ignore_index=True)

# %%
len(combined_df_merged)
# Out:
# 79634

# %%
combined_df_merged.to_csv('combined_df_merged_APRIL_22.csv')

# %% [markdown]
# ## Adding the lookup required matches (DONE)

# %%
# Assuming df is your DataFrame
def parse_season(input_year_test):
    if '.' in input_year_test:
        yearstr = input_year_test.split(".")[2]
        full_num = int('20' + yearstr)
    elif '-' in input_year_test:
        if len(input_year_test.split("-")[2]) == 4:
            yearstr = input_year_test.split("-")[2] #this is a 4 digit number
            full_num = int(yearstr)
        elif len(input_year_test.split("-")[2]) == 2:
            if len(input_year_test.split("-")[0]) == 4:
                yearstr = input_year_test.split("-")[0]
                full_num = int(yearstr)
            else:
                yearstr = input_year_test.split("-")[2] #this is a 2 digit number
                full_num = int('20' + yearstr)
        else:
            print('broke on year parsing', input_year_test.split("-"))
            full_num = None
    else:
        print('Unable to parse input:', input_year_test)
        full_num = None
    return full_num

# %%
big_df_latest = load_csv_dataset('combined_df_merged_APRIL_22.csv')
big_df_latest = big_df_latest.drop(columns={'Unnamed: 0'})
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_86186/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)

# %%
big_df_latest
# Out:
#        Match ID                         Competition  \
# 0          3133  World Cup Qualifiers, Europe, 2018
# 1          3133  World Cup Qualifiers, Europe, 2018
# 2          3133  World Cup Qualifiers, Europe, 2018
# 3          3133  World Cup Qualifiers, Europe, 2018
# 4          3133  World Cup Qualifiers, Europe, 2018
# ...         ...                                 ...
# 79629      2153  World Cup Qualifiers, Africa, 2022
# 79630      2163  World Cup Qualifiers, Africa, 2022
# 79631      3695                      Gold Cup, 2017
# 79632      3732                      Gold Cup, 2019
# 79633      3736                      Gold Cup, 2019
#
#                                Match        Date          Nationality  \
# 0               Luxembourg vs France  25-03-2017           Luxembourg
# 1               Luxembourg vs France  25-03-2017           Luxembourg
# 2               Luxembourg vs France  25-03-2017           Luxembourg
# ...

# %%
lookup_required_matches = load_csv_dataset('Group 1 and 2 (for T) - Find their $ Info/Terrell Lookup Cases - lookup_required_matches_success_rework.csv')
lookup_required_matches = lookup_required_matches.drop(columns={'Unnamed: 0.1', 'Unnamed: 0'})
lookup_required_matches.rename(columns={'Country Code': 'Team Country Code', 'Jersey Name': 'ORIGINAL JERSEY', 'Name Match': 'Name(s) Found'}, inplace=True)


lookup_required_matches['Match Case'] = 'single'
lookup_required_matches['Impute Required?'] = False

lookup_required_matches['Season'] = lookup_required_matches['Date'].apply(parse_season)

lookup_required_matches['Name'] = lookup_required_matches['Name(s) Found']
# Define the desired column order
desired_columns = ['Match ID', 'Competition', 'Match', 'Date', 'Nationality', 'Team Country Code', 
                   'Season', 'Status', 'Name', 'Market Value', 'Lookup Still Required?', 
                   'Lookup Return Case', 'Impute Required?', 'Name(s) Found', 'ORIGINAL JERSEY', 'Match Case']

# Reorder the columns
lookup_required_matches = lookup_required_matches[desired_columns]
lookup_required_matches
# Out:
#       Match ID                         Competition  \
# 0         3136  World Cup Qualifiers, Europe, 2018
# 1         3137  World Cup Qualifiers, Europe, 2018
# 2         3138  World Cup Qualifiers, Europe, 2018
# 3         3139  World Cup Qualifiers, Europe, 2018
# 4         3140  World Cup Qualifiers, Europe, 2018
# ...        ...                                 ...
# 1471      1505            Nations League 2018-2020
# 1472      1506            Nations League 2018-2020
# 1473      1509            Nations League 2018-2020
# 1474      1510            Nations League 2018-2020
# 1475      1511            Nations League 2018-2020
#
#                                           Match        Date  \
# 0                             Serbia vs Georgia  09-10-2017
# 1                  Switzerland vs Faroe Islands  13-11-2016
# 2                             Denmark vs Poland  01-09-2017
# 3     Bosnia-Herzegovina-Herzegovina vs Estonia  06-09-2016
# ...

# %%
combined_df = pd.concat([big_df_latest, lookup_required_matches], ignore_index=True)

# %%
combined_df.to_csv('combined_df_merged_APRIL_23.csv')

# %% [markdown]
# ## Adding cyrillic successes (DONE)

# %%
combined_DF_NEW = load_csv_dataset('combined_df_merged_APRIL_23.csv')
cyrillic_found = load_csv_dataset('Group 1 and 2 (for T) - Find their $ Info/Terrell Lookup Cases - cyrillic_dudes_found_success.csv')
cyrillic_found = cyrillic_found.drop(columns={'Unnamed: 0.1', 'Unnamed: 0', 'ORIGINAL JERSEY', 'DF index'})

cyrillic_found.rename(columns={'Country Code': 'Team Country Code', 'English Name': 'ORIGINAL JERSEY', 'Match(es) Found': 'Name(s) Found'}, inplace=True)

cyrillic_found['Impute Required?'] = False
cyrillic_found['Status'] = 'SUCCESS'

cyrillic_found['Name'] = cyrillic_found['Name(s) Found']

cyrillic_found['Match Case'] = 'Single'
cyrillic_found
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_86186/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)
#       Match ID             Competition      Date                  Match  \
# 0          539  Euros 2016, Qualifiers  12.10.14  Austria vs Montenegro
# 1          539  Euros 2016, Qualifiers  12.10.14  Austria vs Montenegro
# 2          539  Euros 2016, Qualifiers  12.10.14  Austria vs Montenegro
# 3          539  Euros 2016, Qualifiers  12.10.14  Austria vs Montenegro
# 4          539  Euros 2016, Qualifiers  12.10.14  Austria vs Montenegro
# ...        ...                     ...       ...                    ...
# 2112       570  Euros 2016, Qualifiers  13.10.14         Malta vs Italy
# 2113       570  Euros 2016, Qualifiers  13.10.14         Malta vs Italy
# 2114       570  Euros 2016, Qualifiers  13.10.14         Malta vs Italy
# ...

# %%
big_df_combined = pd.concat([combined_DF_NEW, cyrillic_found], ignore_index= True)

# %%
big_df_combined.to_csv('combined_DF_merged_April_23_New.csv')

# %% [markdown]
# ## Adding online lookup 1 found , successes (DONE)

# %%
combined_DF_NEW = load_csv_dataset('combined_DF_merged_April_23_New.csv')
combined_DF_NEW = combined_DF_NEW.drop(columns={'Unnamed: 0', 'Unnamed: 0.1'})
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_60811/1375926879.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)

# %%
online_lookup_1_found = load_csv_dataset('Terrell Lookup Cases - online_lookup_1_complete_success.csv')
online_lookup_1_found = online_lookup_1_found.drop(columns={'Unnamed: 0', 'Unnamed: 0.1', 'Status New'})

# %%
big_df_combined = pd.concat([combined_DF_NEW, online_lookup_1_found], ignore_index=True)

# %%
len(big_df_combined)
# Out:
# 83932

# %%
big_df_combined.to_csv('combined_DF_merged_April_24.csv')

# %% [markdown]
# # May 3 - Adding pink group

# %%
combined_DF_NEWEST = load_csv_dataset('combined_df_may_1.csv')
combined_DF_NEWEST = combined_DF_NEWEST.drop(columns={'Unnamed: 0'})

len(combined_DF_NEWEST)
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_181/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)
# 88216

# %%
pink_weird = load_csv_dataset('PINK GROUP - DONE/pink_group_weird_0_cases.csv')
pink_weird = pink_weird.drop(columns={'Unnamed: 0'})
pink_weird['Name'] = pink_weird['Name(s) Found']
pink_lookup = load_csv_dataset('PINK GROUP - DONE/pink_group_lookup_cases_DONE.csv')
pink_lookup = pink_lookup.drop(columns={'Unnamed: 0', 'Unnamed: 0.1', 'Status New', 'Market Value New'})

pink_Cyrillic = load_csv_dataset('PINK GROUP - DONE/pink_group_cyrillic_dudes_final.csv')
pink_Cyrillic = pink_Cyrillic.drop(columns={'Unnamed: 0', 'DF index', 'Status New'})

pink_Cyrillic = pink_Cyrillic.rename(columns={'Country Code': 'Team Country Code'})
pink_Cyrillic = pink_Cyrillic.rename(columns={'English Name': 'Name'})
pink_Cyrillic = pink_Cyrillic.rename(columns={'Market Value New': 'Market Value'})
pink_Cyrillic['Lookup Still Required?'] = False
pink_Cyrillic['Impute Required?'] = False

# %%
# combined_DF_NEWEST = pd.concat([combined_DF_NEWEST, pink_weird], ignore_index=True)

# %%
# combined_DF_NEWEST = pd.concat([combined_DF_NEWEST, pink_lookup], ignore_index=True)

# %%
combined_DF_NEWEST.head(1)
# Out:
#    Match ID                         Competition                 Match  \
# 0      3133  World Cup Qualifiers, Europe, 2018  Luxembourg vs France
#
#          Date Nationality Team Country Code  Season   Status           Name  \
# 0  25-03-2017  Luxembourg                LU    2017  SUCCESS  Anthony Moris
#
#   Market Value  Lookup Still Required? Lookup Return Case  Impute Required?  \
# 0     400000.0                   False            working             False
#
#    Name(s) Found ORIGINAL JERSEY Match Case
# 0  Anthony Moris         A Moris     single

# %%
new_order = [
    'Match ID', 'Competition', 'Match', 'Date', 'Nationality', 
    'Team Country Code', 'Season', 'Status', 'Name', 
    'Market Value', 'Lookup Still Required?', 'Lookup Return Case', 
    'Impute Required?', 'Name(s) Found', 'ORIGINAL JERSEY', 
    'Match Case'
]

pink_Cyrillic = pink_Cyrillic[new_order] 
pink_Cyrillic['Lookup Still Required?'].fillna(' ')
pink_Cyrillic
# Out:
#      Match ID             Competition                         Match      Date  \
# 0          18    U-20 World Cup, 2015  Myanmar U-20 vs Ukraine U-20  02.06.15
# 1         565  Euros 2016, Qualifiers               Norway vs Italy  09.09.14
# 2         506  Euros 2016, Qualifiers            Romania vs Hungary  11.10.14
# 3         561  Euros 2016, Qualifiers          Russia vs Montenegro  12.10.15
# 4         426  Euros 2016, Qualifiers        Slovakia vs Luxembourg  27.03.15
# ..        ...                     ...                           ...       ...
# 163       373  Euros 2016, Qualifiers              Turkey vs Latvia  03.09.15
# 164       428  Euros 2016, Qualifiers         Ukraine vs Luxembourg  14.06.15
# 165       419  Euros 2016, Qualifiers    Ukraine vs North Macedonia  12.10.14
# 166       415  Euros 2016, Qualifiers           Ukraine vs Slovakia  08.09.14
# 167       404  Euros 2016, Qualifiers               Wales vs Israel  06.09.15
#
# ...

# %%
combined_DF_NEWEST = pd.concat([combined_DF_NEWEST, pink_Cyrillic], ignore_index=True)
combined_DF_NEWEST
# Out:
#        Match ID                         Competition  \
# 0          3133  World Cup Qualifiers, Europe, 2018
# 1          3133  World Cup Qualifiers, Europe, 2018
# 2          3133  World Cup Qualifiers, Europe, 2018
# 3          3133  World Cup Qualifiers, Europe, 2018
# 4          3133  World Cup Qualifiers, Europe, 2018
# ...         ...                                 ...
# 89323       373              Euros 2016, Qualifiers
# 89324       428              Euros 2016, Qualifiers
# 89325       419              Euros 2016, Qualifiers
# 89326       415              Euros 2016, Qualifiers
# 89327       404              Euros 2016, Qualifiers
#
#                             Match        Date   Nationality Team Country Code  \
# 0            Luxembourg vs France  25-03-2017    Luxembourg                LU
# 1            Luxembourg vs France  25-03-2017    Luxembourg                LU
# 2            Luxembourg vs France  25-03-2017    Luxembourg                LU
# ...

# %%
combined_DF_NEWEST.to_csv('combined_DF_NEWEST_may_3.csv')

# %% [markdown]
# ## Pink Group Cases

# %%
combined_df_may_6 = load_csv_dataset('combined_DF_NEWEST_may_3.csv')
combined_df_may_6 = combined_df_may_6.drop(columns={'Unnamed: 0'})
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_55371/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)

# %%
congo_cases = load_csv_dataset('To merge with Combined DF/Terrell Lookup Cases - Congo_Success.csv')
congo_cases = congo_cases.drop(columns={'Unnamed: 0', 'Unnamed: 0.1', 'To Remove', 'Translated Name', 'Original Case'})

congo_cases = congo_cases.rename(columns={'Country Code': 'Team Country Code'})
congo_cases['Impute Required?'] = False
congo_cases['Name'] = congo_cases['Name(s) Found']
congo_cases['Status'] = 'SUCCESS'
congo_cases['Match Case'] = 'single'



congo_cases.at[1, 'Lookup Return Case'] = 'Found in Curr Season'
congo_cases.at[1, 'Market Value'] = 1200000
congo_cases = congo_cases[['Match ID', 'Competition', 'Match', 'Date', 'Nationality', 'Team Country Code', 'Season', 'Status', 'Name', 'Market Value', 'Lookup Still Required?', 'Lookup Return Case', 'Impute Required?', 'Name(s) Found', 'ORIGINAL JERSEY', 'Match Case']]

# %%
combined_df_may_6_new = pd.concat([combined_df_may_6, congo_cases], ignore_index=True)

# %%
combined_df_may_6.head(1)
# Out:
#    Match ID                         Competition                 Match  \
# 0      3133  World Cup Qualifiers, Europe, 2018  Luxembourg vs France
#
#          Date Nationality Team Country Code  Season   Status           Name  \
# 0  25-03-2017  Luxembourg                LU    2017  SUCCESS  Anthony Moris
#
#   Market Value  Lookup Still Required? Lookup Return Case  Impute Required?  \
# 0     400000.0                   False            working             False
#
#    Name(s) Found ORIGINAL JERSEY Match Case
# 0  Anthony Moris         A Moris     single

# %%
congo_cases.head(1)
# Out:
#    Match ID                         Competition            Match        Date  \
# 0      2246  World Cup Qualifiers, Africa, 2026  Zambia vs Congo  17-11-2023
#
#   Nationality Team Country Code  Season   Status                       Name  \
# 0       Congo                CG    2023  SUCCESS  Wolfrigon Mongondza Ngobo
#
#    Market Value  Lookup Still Required? Lookup Return Case  Impute Required?  \
# 0             0                   False         Both Empty             False
#
#                Name(s) Found ORIGINAL JERSEY Match Case
# 0  Wolfrigon Mongondza Ngobo     W Mongondza     single

# %%
combined_df_may_6_new.head(1)
# Out:
#    Match ID                         Competition                 Match  \
# 0      3133  World Cup Qualifiers, Europe, 2018  Luxembourg vs France
#
#          Date Nationality Team Country Code  Season   Status           Name  \
# 0  25-03-2017  Luxembourg                LU    2017  SUCCESS  Anthony Moris
#
#   Market Value  Lookup Still Required? Lookup Return Case  Impute Required?  \
# 0     400000.0                   False            working             False
#
#    Name(s) Found ORIGINAL JERSEY Match Case
# 0  Anthony Moris         A Moris     single

# %%
olympics_edge_cases = load_csv_dataset('To merge with Combined DF/Terrell Lookup Cases - olympic_edge_case_success.csv')
olympics_edge_cases = olympics_edge_cases.drop(columns={'Unnamed: 0', 'Unnamed: 0.1'})
olympics_edge_cases['Status'] = 'SUCCESS'
olympics_edge_cases['Name(s) Found'] = olympics_edge_cases['ORIGINAL JERSEY']
olympics_edge_cases['Match Case'] = 'single'
olympics_edge_cases
# Out:
#     Match ID     Competition                   Match        Date Nationality  \
# 0       1328  Olympics, 2016         Iraq vs Denmark  2016-08-04        Iraq
# 1       1331  Olympics, 2016          Brazil vs Iraq  2016-08-07        Iraq
# 2       1333  Olympics, 2016    South Africa vs Iraq  2016-08-10        Iraq
# 3       1334  Olympics, 2016      Sweden vs Colombia  2016-08-04    Colombia
# 4       1337  Olympics, 2016       Japan vs Colombia  2016-08-07    Colombia
# 5       1339  Olympics, 2016     Colombia vs Nigeria  2016-08-10    Colombia
# 6       1355  Olympics, 2016      Brazil vs Colombia  2016-08-13    Colombia
# 7       1361  Olympics, 2020        Mexico vs France  2021-07-22      France
# 8       1363  Olympics, 2020  France vs South Africa  2021-07-25      France
# 9       1365  Olympics, 2020         France vs Japan  2021-07-28      France
# 10      1380  Olympics, 2020       Brazil vs Germany  2021-07-22      Brazil
# ...

# %%
combined_df_may_6_newest = pd.concat([combined_df_may_6_new, olympics_edge_cases], ignore_index=True)
combined_df_may_6_newest.to_csv('combined_df_may_7_newest.csv')

# %% [markdown]
# ## New name confision

# %%
combined_df_may_8 = load_csv_dataset('combined_df_may_7_newest.csv')
combined_df_may_8 = combined_df_may_8.drop(columns={'Unnamed: 0'})

combined_df_may_8.head(1)
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_56214/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)
#    Match ID                         Competition                 Match  \
# 0      3133  World Cup Qualifiers, Europe, 2018  Luxembourg vs France
#
#          Date Nationality Team Country Code  Season   Status           Name  \
# 0  25-03-2017  Luxembourg                LU    2017  SUCCESS  Anthony Moris
#
#   Market Value  Lookup Still Required? Lookup Return Case  Impute Required?  \
# 0     400000.0                   False            working             False
#
#    Name(s) Found ORIGINAL JERSEY Match Case
# 0  Anthony Moris         A Moris     single

# %%
name_confusion = load_csv_dataset('April 25 - CONCACAF & CONMEBOL OUT - DATA CSVs/Red Groups/ADD TO COMBINED DF/name_confusion_edited.csv')
name_confusion = name_confusion.drop(columns={'Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.2', 'Translated Name', 'Original Case', 'To Remove', 'Status New'})
name_confusion['Impute Required?'] = False
name_confusion['Status'] = 'SUCCESS'

name_confusion['Name'] = name_confusion['Name(s) Found']
name_confusion = name_confusion.rename(columns={'Country Code': "Team Country Code", 'Market Value New': 'Market Value'})

# Define the desired column order
desired_order = [
    'Match ID', 'Competition', 'Match', 'Date', 'Nationality', 'Team Country Code', 
    'Season', 'Status', 'Name', 'Market Value', 'Lookup Still Required?', 
    'Lookup Return Case', 'Impute Required?', 'Name(s) Found', 'ORIGINAL JERSEY', 
    'Match Case'
]

# Reorder the columns
name_confusion = name_confusion[desired_order]
name_confusion
# Out:
#      Match ID                         Competition  \
# 0         310                      World Cup 2022
# 1         318                      World Cup 2022
# 2        1873            Nations League 2022-2023
# 3         951              Euros 2024, Qualifiers
# 4         953              Euros 2024, Qualifiers
# ..        ...                                 ...
# 106      1986  World Cup Qualifiers, Africa, 2018
# 107      2282    World Cup Qualifiers, Asia, 2018
# 108      2157  World Cup Qualifiers, Africa, 2022
# 109      2163  World Cup Qualifiers, Africa, 2022
# 110      2165  World Cup Qualifiers, Africa, 2022
#
#                                       Match        Date   Nationality  \
# 0                           England vs Iran    21.11.22          Iran
# 1                    Poland vs Saudi Arabia    26.11.22  Saudi Arabia
# 2                         Cyprus vs Estonia    29.03.22        Cyprus
# 3                          Wales vs Croatia    15.10.23         Wales
# ...

# %%
combined_df_may_8_new = pd.concat([combined_df_may_8, name_confusion], ignore_index=True)
combined_df_may_8_new.to_csv('combined_df_may_8_new.csv')

# %% [markdown]
# ## Other Cases group

# %%
other_cases_group = load_csv_dataset('April 25 - CONCACAF & CONMEBOL OUT - DATA CSVs/Red Groups/ADD TO COMBINED DF/other_cases_DONE.csv')
other_cases_group = other_cases_group.drop(columns={'Unnamed: 0.1', 'Unnamed: 0', 'Translated Name', 'To Remove', 'Status New'})
for index, row in other_cases_group.iterrows():
    if row['Status'] != 'FAIL - NO DATA':
        other_cases_group.at[index, 'Status'] = 'SUCCESS'
other_cases_group = other_cases_group.rename(columns={"Market Value New": 'Market Value', 'Country Code': 'Team Country Code'})
other_cases_group['Name'] = other_cases_group['Name(s) Found']

other_cases_group['Impute Required?'] = False
desired_columns = [
    'Match ID', 'Competition', 'Match', 'Date', 'Nationality', 
    'Team Country Code', 'Season', 'Status', 'Name', 'Market Value', 
    'Lookup Still Required?', 'Lookup Return Case', 'Impute Required?', 
    'Name(s) Found', 'ORIGINAL JERSEY', 'Match Case'
]

# Reorder columns
other_cases_group = other_cases_group[desired_columns]
other_cases_group
# Out:
#      Match ID                       Competition                        Match  \
# 0        2681  World Cup Qualifiers, Asia, 2022        Thailand vs Indonesia
# 1        2681  World Cup Qualifiers, Asia, 2022        Thailand vs Indonesia
# 2        2683  World Cup Qualifiers, Asia, 2022        Saudi Arabia vs Yemen
# 3        2686  World Cup Qualifiers, Asia, 2022  Turkmenistan vs North Korea
# 4        2686  World Cup Qualifiers, Asia, 2022  Turkmenistan vs North Korea
# ..        ...                               ...                          ...
# 972      1495          Nations League 2018-2020            Latvia vs Georgia
# 973      1497          Nations League 2018-2020           Andorra vs Georgia
# 974      1499          Nations League 2018-2020        Georgia vs Kazakhstan
# 975      1504          Nations League 2018-2020        Belarus vs Luxembourg
# 976      1506          Nations League 2018-2020           Belarus vs Moldova
#
# ...

# %%
combined_df_may_8_newest = load_csv_dataset('combined_df_may_8_new.csv')
combined_df_may_8_newest = combined_df_may_8_newest.drop(columns={'Unnamed: 0'})
combined_df_may_8_newest
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_56214/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)
#        Match ID                         Competition  \
# 0          3133  World Cup Qualifiers, Europe, 2018
# 1          3133  World Cup Qualifiers, Europe, 2018
# 2          3133  World Cup Qualifiers, Europe, 2018
# 3          3133  World Cup Qualifiers, Europe, 2018
# 4          3133  World Cup Qualifiers, Europe, 2018
# ...         ...                                 ...
# 89570      1986  World Cup Qualifiers, Africa, 2018
# 89571      2282    World Cup Qualifiers, Asia, 2018
# 89572      2157  World Cup Qualifiers, Africa, 2022
# 89573      2163  World Cup Qualifiers, Africa, 2022
# 89574      2165  World Cup Qualifiers, Africa, 2022
#
#                                         Match        Date Nationality  \
# ...

# %%
for index, row in combined_df_may_8_newest_BIG.iterrows():
    if row['Status'] == 'FAIL':
        combined_df_may_8_newest_BIG.at[index, 'Status'] = 'SUCCESS'

combined_df_may_8_newest_BIG['Status'].value_counts()
# Out:
# Status
# SUCCESS           90136
# FAIL - NO DATA      295
# FAIL - NEW           91
# FAIL - LARGE         30
# Name: count, dtype: int64

# %%
combined_df_may_8_newest_BIG = pd.concat([combined_df_may_8_newest, other_cases_group], ignore_index=True)

# %%
combined_df_may_8_newest_BIG.to_csv('combined_DF_may_8_Latest.csv')

# %%
len(combined_df_may_8_newest_BIG)
# Out:
# 90552

# %% [markdown]
# ## New olympics group

# %%
combined_df_may_10 = load_csv_dataset('combined_DF_may_8_Latest.csv')
combined_df_may_10 = combined_df_may_10.drop(columns={'Unnamed: 0'})
combined_df_may_10.head(1)
# Out:
# /var/folders/vw/z2xv57_n70l_szw_fr80j5km0000gn/T/ipykernel_56214/1375926879.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)
#    Match ID                         Competition                 Match  \
# 0      3133  World Cup Qualifiers, Europe, 2018  Luxembourg vs France
#
#          Date Nationality Team Country Code  Season   Status           Name  \
# 0  25-03-2017  Luxembourg                LU    2017  SUCCESS  Anthony Moris
#
#   Market Value  Lookup Still Required? Lookup Return Case  Impute Required?  \
# 0     400000.0                   False            working             False
#
#    Name(s) Found ORIGINAL JERSEY Match Case
# 0  Anthony Moris         A Moris     single

# %%
new_olympics_group = load_csv_dataset('Olympics group - MERGED BOTH GROUPS.csv')
new_olympics_group = new_olympics_group.drop(columns={'Unnamed: 0', 'TM Link'})
new_olympics_group
# Out:
#      Match ID     Competition                    Match        Date  \
# 0        1339  Olympics, 2016      Colombia vs Nigeria  08-10-2016
# 1        1355  Olympics, 2016       Brazil vs Colombia  08-13-2016
# 2        1362  Olympics, 2020    Japan vs South Africa  07-22-2021
# 3        1364  Olympics, 2020          Japan vs Mexico  07-25-2021
# 4        1386  Olympics, 2020     Japan vs New Zealand  07-31-2021
# ..        ...             ...                      ...         ...
# 201      1343  Olympics, 2016   Germany vs South Korea  2016-08-07
# 202      1375  Olympics, 2020       Egypt vs Argentina  2021-07-25
# 203      1378  Olympics, 2020       Spain vs Argentina  2021-07-28
# 204      1377  Olympics, 2020       Australia vs Egypt  2021-07-28
# 205      1330  Olympics, 2016  Denmark vs South Africa  2016-08-07
#
#      Nationality Team Country Code  Season   Status                   Name  \
# 0       Colombia                CO    2016  SUCCESS         Cristián Borja
# ...

# %%
merged_df_combined = pd.concat([combined_df_may_10, new_olympics_group], ignore_index=True)
merged_df_combined.to_csv('combined_df_may_10.csv')
